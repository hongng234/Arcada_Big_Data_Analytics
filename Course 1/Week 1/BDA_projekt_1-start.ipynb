# %% [markdown]
# # Project 1

# %% [markdown]
# - load the dataset https://data.melbourne.vic.gov.au/api/views/ez6b-syvw/rows.csv into a Python Pandas dataframe
# - calculate the median and
# - standard deviation for each place of measurement.
# - visualize each time series for respective places in the same figure.
# - The x-axis should have the correct time index indicated in the figure.

# %% [markdown]
# If Python is totaly new for you take a short quided tour to the language: https://www.w3schools.com/python/python_intro.asp or more comprehensive one: https://wiki.python.org/moin/BeginnersGuide
#
# Afterwords you will always need to consult the documentation: https://docs.python.org/3.6/
#
# You will also find relevant things at https://docs.python.org/3.6/faq/programming.html
#
# Before you strart this exersise, read http://pandas.pydata.org/pandas-docs/stable/dsintro.html

# %%
# activate pandas package
import pandas as pd

# %% [markdown]
# Read in the dowloaded CVS file into pandas DataFrame object with `read_cvs()`
#
# If you get `FileNotFoundError: File b'Sensor_readings.csv' does not exist` check that your file is in the same directory as the active `.ipynb file` or provide full file path.

# %%
data = pd.read_csv("Sensor_readings.csv")
data.describe()
# Out:
#        boardtype       boardid      temp_max      temp_min      temp_avg  \
# count    56570.0  56570.000000  56570.000000  56570.000000  56570.000000
# mean         1.0    507.918738     18.522650     18.522650     18.522650
# std          0.0      2.673337      5.498701      5.498701      5.498701
# min          1.0    501.000000      4.200000      4.200000      4.200000
# 25%          1.0    506.000000     14.800000     14.800000     14.800000
# 50%          1.0    509.000000     17.700000     17.700000     17.700000
# 75%          1.0    510.000000     21.900000     21.900000     21.900000
# max          1.0    511.000000     45.200000     45.200000     45.200000
#
#           light_max     light_min     light_avg  humidity_min  humidity_max  \
# count  56570.000000  56570.000000  56570.000000  56570.000000  56570.000000
# mean      48.674527     48.674527     48.674527     49.431043     49.431043
# std       43.973493     43.973493     43.973493     13.413633     13.413633
# min        0.000000      0.000000      0.000000    -24.900000    -24.900000
# 25%        2.900000      2.900000      2.900000     41.700000     41.700000
# 50%       49.900000     49.900000     49.900000     51.000000     51.000000
# 75%       94.900000     94.900000     94.900000     58.700000     58.700000
# max       98.700000     98.700000     98.700000    102.500000    102.500000
#
#        humidity_avg      latitude     longitude     elevation  Position
# count  56570.000000  56570.000000  56570.000000  34975.000000       0.0
# mean      49.431043    -37.818444    144.950806     12.973810       NaN
# std       13.413633      0.002513      0.017177     14.777655       NaN
# min      -24.900000    -37.820354    144.940482      0.030000       NaN
# 25%       41.700000    -37.819904    144.940485      0.030000       NaN
# 50%       51.000000    -37.819712    144.941325      2.740000       NaN
# 75%       58.700000    -37.814922    144.979018     29.910000       NaN
# max      102.500000    -37.813073    144.982258     38.790000       NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56570 entries, 0 to 56569
# Data columns (total 20 columns):
# timestamp       56570 non-null object
# mac             56570 non-null object
# boardtype       56570 non-null int64
# boardid         56570 non-null int64
# temp_max        56570 non-null float64
# temp_min        56570 non-null float64
# temp_avg        56570 non-null float64
# light_max       56570 non-null float64
# light_min       56570 non-null float64
# light_avg       56570 non-null float64
# humidity_min    56570 non-null float64
# humidity_max    56570 non-null float64
# humidity_avg    56570 non-null float64
# model           56570 non-null object
# latitude        56570 non-null float64
# longitude       56570 non-null float64
# elevation       34975 non-null float64
# location        56570 non-null object
# rowid           56570 non-null object
# Position        0 non-null float64
# dtypes: float64(13), int64(2), object(5)
# memory usage: 8.6+ MB

# %% [markdown]
# `data` is now an instance of [class DataFrame](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html)
#
# `head()` is a method defined in the class

# %%
data.head(9)
# Out:
#                 timestamp               mac  boardtype  boardid  temp_max  \
# 0  12/15/2014 01:40:00 AM  0013a20040b4b755          1      508      21.6
# 1  12/15/2014 01:40:00 AM  0013a20040b516ed          1      505      23.2
# 2  12/15/2014 01:45:00 AM  0013a20040b516f6          1      507      21.6
# 3  12/15/2014 01:45:00 AM  0013a20040b5b318          1      502      21.3
# 4  12/15/2014 01:45:00 AM  0013a20040b315ec          1      501      22.9
# 5  12/15/2014 01:50:00 AM  0013a20040b4b755          1      508      21.3
# 6  12/15/2014 01:55:00 AM  0013a20040b516ed          1      505      23.2
# 7  12/15/2014 01:55:00 AM  0013a20040b516f6          1      507      21.6
# 8  12/15/2014 01:55:00 AM  0013a20040b5b318          1      502      21.6
#
#    temp_min  temp_avg  light_max  light_min  light_avg  humidity_min  \
# 0      21.6      21.6       96.4       96.4       96.4          41.2
# 1      23.2      23.2       93.5       93.5       93.5          48.3
# 2      21.6      21.6       97.2       97.2       97.2          44.8
# 3      21.3      21.3       97.4       97.4       97.4          45.3
# 4      22.9      22.9       97.4       97.4       97.4          43.1
# 5      21.3      21.3       96.4       96.4       96.4          41.2
# 6      23.2      23.2       93.5       93.5       93.5          47.0
# 7      21.6      21.6       97.2       97.2       97.2          44.5
# 8      21.6      21.6       97.4       97.4       97.4          45.3
#
#    humidity_max  humidity_avg model   latitude   longitude  elevation  \
# 0          41.2          41.2   ENV -37.813408  144.979492      30.10
# 1          48.3          48.3   ENV -37.813073  144.980406      29.91
# 2          44.8          44.8   ENV -37.814922  144.982258      38.79
# 3          45.3          45.3   ENV -37.814610  144.979018      22.57
# 4          43.1          43.1   ENV -37.814808  144.980999      29.96
# 5          41.2          41.2   ENV -37.813408  144.979492      30.10
# 6          47.0          47.0   ENV -37.813073  144.980406      29.91
# 7          44.5          44.5   ENV -37.814922  144.982258      38.79
# 8          45.3          45.3   ENV -37.814610  144.979018      22.57
#
#           location               rowid  Position
# 0  Fitzroy Gardens  508-20141215014000       NaN
# 1  Fitzroy Gardens  505-20141215014000       NaN
# 2  Fitzroy Gardens  507-20141215014500       NaN
# 3  Fitzroy Gardens  502-20141215014500       NaN
# 4  Fitzroy Gardens  501-20141215014500       NaN
# 5  Fitzroy Gardens  508-20141215015000       NaN
# 6  Fitzroy Gardens  505-20141215015500       NaN
# 7  Fitzroy Gardens  507-20141215015500       NaN
# 8  Fitzroy Gardens  502-20141215015500       NaN

# %% [markdown]
# `shape` is an attribute of class DataFrame, note absence of `()`

# %%
data.shape
# Out:
# (56570, 20)

# %%
data.info(verbose=True, memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56570 entries, 0 to 56569
# Data columns (total 20 columns):
# timestamp       56570 non-null object
# mac             56570 non-null object
# boardtype       56570 non-null int64
# boardid         56570 non-null int64
# temp_max        56570 non-null float64
# temp_min        56570 non-null float64
# temp_avg        56570 non-null float64
# light_max       56570 non-null float64
# light_min       56570 non-null float64
# light_avg       56570 non-null float64
# humidity_min    56570 non-null float64
# humidity_max    56570 non-null float64
# humidity_avg    56570 non-null float64
# model           56570 non-null object
# latitude        56570 non-null float64
# longitude       56570 non-null float64
# elevation       34975 non-null float64
# location        56570 non-null object
# rowid           56570 non-null object
# Position        0 non-null float64
# dtypes: float64(13), int64(2), object(5)
# memory usage: 25.9 MB

# %%
# some columns are totaly useless, you may whant to drop them.
data.drop(['mac', 'boardtype', 'Position', 'model', 'rowid'], axis=1, inplace=True)

# %%
data
# Out:
#                     timestamp  boardid  temp_max  temp_min  temp_avg  \
# 0      12/15/2014 01:40:00 AM      508      21.6      21.6      21.6
# 1      12/15/2014 01:40:00 AM      505      23.2      23.2      23.2
# 2      12/15/2014 01:45:00 AM      507      21.6      21.6      21.6
# 3      12/15/2014 01:45:00 AM      502      21.3      21.3      21.3
# 4      12/15/2014 01:45:00 AM      501      22.9      22.9      22.9
# 5      12/15/2014 01:50:00 AM      508      21.3      21.3      21.3
# 6      12/15/2014 01:55:00 AM      505      23.2      23.2      23.2
# 7      12/15/2014 01:55:00 AM      507      21.6      21.6      21.6
# 8      12/15/2014 01:55:00 AM      502      21.6      21.6      21.6
# 9      12/15/2014 02:00:00 AM      501      23.5      23.5      23.5
# 10     12/15/2014 02:00:00 AM      508      21.6      21.6      21.6
# 11     12/15/2014 03:55:00 AM      506      23.5      23.5      23.5
# 12     12/15/2014 03:55:00 AM      511      23.5      23.5      23.5
# 13     12/15/2014 04:00:00 AM      510      24.2      24.2      24.2
# 14     12/15/2014 04:00:00 AM      509      22.9      22.9      22.9
# 15     12/15/2014 04:05:00 AM      506      24.5      24.5      24.5
# 16     12/15/2014 04:05:00 AM      511      22.9      22.9      22.9
# 17     12/15/2014 04:10:00 AM      510      24.5      24.5      24.5
# 18     12/15/2014 04:10:00 AM      509      22.6      22.6      22.6
# 19     12/15/2014 04:20:00 AM      509      22.9      22.9      22.9
# 20     12/15/2014 04:30:00 AM      509      21.9      21.9      21.9
# 21     12/15/2014 04:55:00 AM      511      22.6      22.6      22.6
# 22     12/15/2014 05:20:00 AM      509      22.9      22.9      22.9
# 23     12/15/2014 05:40:00 AM      511      21.3      21.3      21.3
# 24     12/15/2014 05:45:00 AM      509      21.6      21.6      21.6
# 25     12/15/2014 05:50:00 AM      511      21.0      21.0      21.0
# 26     12/15/2014 05:55:00 AM      506      21.0      21.0      21.0
# 27     12/15/2014 06:05:00 AM      509      21.3      21.3      21.3
# 28     12/15/2014 06:05:00 AM      506      20.6      20.6      20.6
# 29     12/15/2014 06:10:00 AM      511      21.3      21.3      21.3
# ...                       ...      ...       ...       ...       ...
# 56540  06/05/2015 01:20:00 AM      506       7.7       7.7       7.7
# 56541  06/05/2015 01:20:00 AM      509       7.7       7.7       7.7
# 56542  06/05/2015 01:30:00 AM      506       7.7       7.7       7.7
# 56543  06/05/2015 01:30:00 AM      509       7.7       7.7       7.7
# 56544  06/05/2015 01:40:00 AM      510       7.1       7.1       7.1
# 56545  06/05/2015 01:45:00 AM      509       8.1       8.1       8.1
# 56546  06/05/2015 01:55:00 AM      509       8.1       8.1       8.1
# 56547  06/05/2015 02:00:00 AM      510       7.4       7.4       7.4
# 56548  06/05/2015 02:05:00 AM      509       8.1       8.1       8.1
# 56549  06/05/2015 02:10:00 AM      510       7.1       7.1       7.1
# 56550  06/05/2015 02:15:00 AM      509       8.1       8.1       8.1
# 56551  06/05/2015 02:20:00 AM      510       7.1       7.1       7.1
# 56552  06/05/2015 02:25:00 AM      509       8.1       8.1       8.1
# 56553  06/05/2015 02:30:00 AM      510       7.1       7.1       7.1
# 56554  06/05/2015 02:35:00 AM      509       7.7       7.7       7.7
# 56555  06/05/2015 02:45:00 AM      509       7.7       7.7       7.7
# 56556  06/05/2015 02:50:00 AM      510       6.8       6.8       6.8
# 56557  06/05/2015 02:55:00 AM      509       7.7       7.7       7.7
# 56558  06/05/2015 03:05:00 AM      506       7.7       7.7       7.7
# 56559  06/05/2015 03:05:00 AM      509       7.7       7.7       7.7
# 56560  06/05/2015 03:15:00 AM      509       7.7       7.7       7.7
# 56561  06/05/2015 03:25:00 AM      509       7.7       7.7       7.7
# 56562  06/05/2015 03:35:00 AM      509       8.1       8.1       8.1
# 56563  06/05/2015 03:45:00 AM      510       7.4       7.4       7.4
# 56564  06/05/2015 03:45:00 AM      509       8.1       8.1       8.1
# 56565  06/05/2015 03:55:00 AM      509       8.1       8.1       8.1
# 56566  06/05/2015 04:05:00 AM      510       7.4       7.4       7.4
# 56567  06/05/2015 04:05:00 AM      509       8.1       8.1       8.1
# 56568  06/05/2015 04:15:00 AM      506       8.1       8.1       8.1
# 56569  06/05/2015 04:15:00 AM      509       8.1       8.1       8.1
#
#        light_max  light_min  light_avg  humidity_min  humidity_max  \
# 0           96.4       96.4       96.4          41.2          41.2
# 1           93.5       93.5       93.5          48.3          48.3
# 2           97.2       97.2       97.2          44.8          44.8
# 3           97.4       97.4       97.4          45.3          45.3
# 4           97.4       97.4       97.4          43.1          43.1
# 5           96.4       96.4       96.4          41.2          41.2
# 6           93.5       93.5       93.5          47.0          47.0
# 7           97.2       97.2       97.2          44.5          44.5
# 8           97.4       97.4       97.4          45.3          45.3
# 9           97.4       97.4       97.4          43.7          43.7
# 10          96.4       96.4       96.4          41.0          41.0
# 11          94.8       94.8       94.8          44.5          44.5
# 12          96.3       96.3       96.3          43.1          43.1
# 13          97.6       97.6       97.6          43.4          43.4
# 14          97.8       97.8       97.8          46.6          46.6
# 15          98.2       98.2       98.2          44.5          44.5
# 16          98.0       98.0       98.0          42.9          42.9
# 17          98.2       98.2       98.2          42.6          42.6
# 18          97.6       97.6       97.6          47.3          47.3
# 19          97.0       97.0       97.0          46.9          46.9
# 20          96.7       96.7       96.7          49.1          49.1
# 21          97.8       97.8       97.8          45.9          45.9
# 22          96.4       96.4       96.4          48.1          48.1
# 23          95.7       95.7       95.7          48.1          48.1
# 24          94.2       94.2       94.2          52.2          52.2
# 25          95.6       95.6       95.6          49.4          49.4
# 26          93.6       93.6       93.6          53.3          53.3
# 27          94.7       94.7       94.7          52.6          52.6
# 28          94.0       94.0       94.0          52.1          52.1
# 29          96.8       96.8       96.8          48.5          48.5
# ...          ...        ...        ...           ...           ...
# 56540        6.1        6.1        6.1          56.5          56.5
# 56541        2.3        2.3        2.3          64.5          64.5
# 56542        5.6        5.6        5.6          56.2          56.2
# 56543        2.4        2.4        2.4          64.4          64.4
# 56544        1.9        1.9        1.9          54.6          54.6
# 56545        2.4        2.4        2.4          64.7          64.7
# 56546        2.5        2.5        2.5          63.6          63.6
# 56547        2.3        2.3        2.3          54.4          54.4
# 56548        2.5        2.5        2.5          63.6          63.6
# 56549        2.3        2.3        2.3          54.3          54.3
# 56550        2.5        2.5        2.5          64.1          64.1
# 56551        2.3        2.3        2.3          53.8          53.8
# 56552        2.4        2.4        2.4          63.7          63.7
# 56553        2.2        2.2        2.2          54.6          54.6
# 56554        2.4        2.4        2.4          64.4          64.4
# 56555        2.4        2.4        2.4          64.2          64.2
# 56556        2.3        2.3        2.3          54.8          54.8
# 56557        2.4        2.4        2.4          64.7          64.7
# 56558        8.2        8.2        8.2          56.3          56.3
# 56559        2.5        2.5        2.5          63.9          63.9
# 56560        2.5        2.5        2.5          64.4          64.4
# 56561        2.5        2.5        2.5          64.4          64.4
# 56562        2.5        2.5        2.5          63.7          63.7
# 56563        3.8        3.8        3.8          53.8          53.8
# 56564        2.6        2.6        2.6          64.2          64.2
# 56565        2.6        2.6        2.6          63.4          63.4
# 56566        3.9        3.9        3.9          54.4          54.4
# 56567        2.6        2.6        2.6          63.9          63.9
# 56568        8.4        8.4        8.4          55.4          55.4
# 56569        2.6        2.6        2.6          63.7          63.7
#
#        humidity_avg   latitude   longitude  elevation           location
# 0              41.2 -37.813408  144.979492      30.10    Fitzroy Gardens
# 1              48.3 -37.813073  144.980406      29.91    Fitzroy Gardens
# 2              44.8 -37.814922  144.982258      38.79    Fitzroy Gardens
# 3              45.3 -37.814610  144.979018      22.57    Fitzroy Gardens
# 4              43.1 -37.814808  144.980999      29.96    Fitzroy Gardens
# 5              41.2 -37.813408  144.979492      30.10    Fitzroy Gardens
# 6              47.0 -37.813073  144.980406      29.91    Fitzroy Gardens
# 7              44.5 -37.814922  144.982258      38.79    Fitzroy Gardens
# 8              45.3 -37.814610  144.979018      22.57    Fitzroy Gardens
# 9              43.7 -37.814808  144.980999      29.96    Fitzroy Gardens
# 10             41.0 -37.813408  144.979492      30.10    Fitzroy Gardens
# 11             44.5 -37.820354  144.940482        NaN  Docklands Library
# 12             43.1 -37.819500  144.941889        NaN  Docklands Library
# 13             43.4 -37.819712  144.941325        NaN  Docklands Library
# 14             46.6 -37.819904  144.940485        NaN  Docklands Library
# 15             44.5 -37.820354  144.940482        NaN  Docklands Library
# 16             42.9 -37.819500  144.941889        NaN  Docklands Library
# 17             42.6 -37.819712  144.941325        NaN  Docklands Library
# 18             47.3 -37.819904  144.940485        NaN  Docklands Library
# 19             46.9 -37.819904  144.940485        NaN  Docklands Library
# 20             49.1 -37.819904  144.940485        NaN  Docklands Library
# 21             45.9 -37.819500  144.941889        NaN  Docklands Library
# 22             48.1 -37.819904  144.940485        NaN  Docklands Library
# 23             48.1 -37.819500  144.941889        NaN  Docklands Library
# 24             52.2 -37.819904  144.940485        NaN  Docklands Library
# 25             49.4 -37.819500  144.941889        NaN  Docklands Library
# 26             53.3 -37.820354  144.940482        NaN  Docklands Library
# 27             52.6 -37.819904  144.940485        NaN  Docklands Library
# 28             52.1 -37.820354  144.940482        NaN  Docklands Library
# 29             48.5 -37.819500  144.941889        NaN  Docklands Library
# ...             ...        ...         ...        ...                ...
# 56540          56.5 -37.820354  144.940482       0.71  Docklands Library
# 56541          64.5 -37.819904  144.940485       0.03  Docklands Library
# 56542          56.2 -37.820354  144.940482       0.71  Docklands Library
# 56543          64.4 -37.819904  144.940485       0.03  Docklands Library
# 56544          54.6 -37.819712  144.941325       2.74  Docklands Library
# 56545          64.7 -37.819904  144.940485       0.03  Docklands Library
# 56546          63.6 -37.819904  144.940485       0.03  Docklands Library
# 56547          54.4 -37.819712  144.941325       2.74  Docklands Library
# 56548          63.6 -37.819904  144.940485       0.03  Docklands Library
# 56549          54.3 -37.819712  144.941325       2.74  Docklands Library
# 56550          64.1 -37.819904  144.940485       0.03  Docklands Library
# 56551          53.8 -37.819712  144.941325       2.74  Docklands Library
# 56552          63.7 -37.819904  144.940485       0.03  Docklands Library
# 56553          54.6 -37.819712  144.941325       2.74  Docklands Library
# 56554          64.4 -37.819904  144.940485       0.03  Docklands Library
# 56555          64.2 -37.819904  144.940485       0.03  Docklands Library
# 56556          54.8 -37.819712  144.941325       2.74  Docklands Library
# 56557          64.7 -37.819904  144.940485       0.03  Docklands Library
# 56558          56.3 -37.820354  144.940482       0.71  Docklands Library
# 56559          63.9 -37.819904  144.940485       0.03  Docklands Library
# 56560          64.4 -37.819904  144.940485       0.03  Docklands Library
# 56561          64.4 -37.819904  144.940485       0.03  Docklands Library
# 56562          63.7 -37.819904  144.940485       0.03  Docklands Library
# 56563          53.8 -37.819712  144.941325       2.74  Docklands Library
# 56564          64.2 -37.819904  144.940485       0.03  Docklands Library
# 56565          63.4 -37.819904  144.940485       0.03  Docklands Library
# 56566          54.4 -37.819712  144.941325       2.74  Docklands Library
# 56567          63.9 -37.819904  144.940485       0.03  Docklands Library
# 56568          55.4 -37.820354  144.940482       0.71  Docklands Library
# 56569          63.7 -37.819904  144.940485       0.03  Docklands Library
#
# [56570 rows x 15 columns]

# %% [markdown]
# Hmm, looks like some columns hold same values. Check if there are any rows where `temp_max`, `temp_min` and `temp_avg` are different. If there are none - drop `temp_max` and `temp_min`.

# %% [markdown]
# Check the amount of rows in the dataframe

# %%
len(data)
# Out:
# 56570

# %% [markdown]
# Compare the number to the amount of rows `len(data)` in the filtered dataframe,
# where values of `temp_min` and `temp_max` are the same in the same row.
# Note: you may sometimes use different syntax for column selection in pandas.
#
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#
# Attribute-access is nice, because it allows tab-completion
#
# https://ipython.readthedocs.io/en/stable/interactive/reference.html?highlight=completion#command-line-completion

# %%
#Show records that temp_max = temp_min
len(data[data.temp_max == data['temp_min']])
# Out:
# 56570

# %%
#Show records that temp_max = temp_avg
len(data.query('temp_max == temp_avg'))
# Out:
# 56570

# %% [markdown]
# Then you are interested in how many different locations the data holds. The [`unique()` method](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.unique.html) from `Series` class will be helpful.

# %%
#Show all unique rows
data.location.unique()
# Out:
# array(['Fitzroy Gardens', 'Docklands Library'], dtype=object)

# %% [markdown]
# Can you see how many rows are from Fitzroy Gardens?

# %%
len(data[data.location == 'XXX'])
# Out:
# 0

# %%
data
# Out:
#                     timestamp  boardid  temp_max  temp_min  temp_avg  \
# 0      12/15/2014 01:40:00 AM      508      21.6      21.6      21.6
# 1      12/15/2014 01:40:00 AM      505      23.2      23.2      23.2
# 2      12/15/2014 01:45:00 AM      507      21.6      21.6      21.6
# 3      12/15/2014 01:45:00 AM      502      21.3      21.3      21.3
# 4      12/15/2014 01:45:00 AM      501      22.9      22.9      22.9
# 5      12/15/2014 01:50:00 AM      508      21.3      21.3      21.3
# 6      12/15/2014 01:55:00 AM      505      23.2      23.2      23.2
# 7      12/15/2014 01:55:00 AM      507      21.6      21.6      21.6
# 8      12/15/2014 01:55:00 AM      502      21.6      21.6      21.6
# 9      12/15/2014 02:00:00 AM      501      23.5      23.5      23.5
# 10     12/15/2014 02:00:00 AM      508      21.6      21.6      21.6
# 11     12/15/2014 03:55:00 AM      506      23.5      23.5      23.5
# 12     12/15/2014 03:55:00 AM      511      23.5      23.5      23.5
# 13     12/15/2014 04:00:00 AM      510      24.2      24.2      24.2
# 14     12/15/2014 04:00:00 AM      509      22.9      22.9      22.9
# 15     12/15/2014 04:05:00 AM      506      24.5      24.5      24.5
# 16     12/15/2014 04:05:00 AM      511      22.9      22.9      22.9
# 17     12/15/2014 04:10:00 AM      510      24.5      24.5      24.5
# 18     12/15/2014 04:10:00 AM      509      22.6      22.6      22.6
# 19     12/15/2014 04:20:00 AM      509      22.9      22.9      22.9
# 20     12/15/2014 04:30:00 AM      509      21.9      21.9      21.9
# 21     12/15/2014 04:55:00 AM      511      22.6      22.6      22.6
# 22     12/15/2014 05:20:00 AM      509      22.9      22.9      22.9
# 23     12/15/2014 05:40:00 AM      511      21.3      21.3      21.3
# 24     12/15/2014 05:45:00 AM      509      21.6      21.6      21.6
# 25     12/15/2014 05:50:00 AM      511      21.0      21.0      21.0
# 26     12/15/2014 05:55:00 AM      506      21.0      21.0      21.0
# 27     12/15/2014 06:05:00 AM      509      21.3      21.3      21.3
# 28     12/15/2014 06:05:00 AM      506      20.6      20.6      20.6
# 29     12/15/2014 06:10:00 AM      511      21.3      21.3      21.3
# ...                       ...      ...       ...       ...       ...
# 56540  06/05/2015 01:20:00 AM      506       7.7       7.7       7.7
# 56541  06/05/2015 01:20:00 AM      509       7.7       7.7       7.7
# 56542  06/05/2015 01:30:00 AM      506       7.7       7.7       7.7
# 56543  06/05/2015 01:30:00 AM      509       7.7       7.7       7.7
# 56544  06/05/2015 01:40:00 AM      510       7.1       7.1       7.1
# 56545  06/05/2015 01:45:00 AM      509       8.1       8.1       8.1
# 56546  06/05/2015 01:55:00 AM      509       8.1       8.1       8.1
# 56547  06/05/2015 02:00:00 AM      510       7.4       7.4       7.4
# 56548  06/05/2015 02:05:00 AM      509       8.1       8.1       8.1
# 56549  06/05/2015 02:10:00 AM      510       7.1       7.1       7.1
# 56550  06/05/2015 02:15:00 AM      509       8.1       8.1       8.1
# 56551  06/05/2015 02:20:00 AM      510       7.1       7.1       7.1
# 56552  06/05/2015 02:25:00 AM      509       8.1       8.1       8.1
# 56553  06/05/2015 02:30:00 AM      510       7.1       7.1       7.1
# 56554  06/05/2015 02:35:00 AM      509       7.7       7.7       7.7
# 56555  06/05/2015 02:45:00 AM      509       7.7       7.7       7.7
# 56556  06/05/2015 02:50:00 AM      510       6.8       6.8       6.8
# 56557  06/05/2015 02:55:00 AM      509       7.7       7.7       7.7
# 56558  06/05/2015 03:05:00 AM      506       7.7       7.7       7.7
# 56559  06/05/2015 03:05:00 AM      509       7.7       7.7       7.7
# 56560  06/05/2015 03:15:00 AM      509       7.7       7.7       7.7
# 56561  06/05/2015 03:25:00 AM      509       7.7       7.7       7.7
# 56562  06/05/2015 03:35:00 AM      509       8.1       8.1       8.1
# 56563  06/05/2015 03:45:00 AM      510       7.4       7.4       7.4
# 56564  06/05/2015 03:45:00 AM      509       8.1       8.1       8.1
# 56565  06/05/2015 03:55:00 AM      509       8.1       8.1       8.1
# 56566  06/05/2015 04:05:00 AM      510       7.4       7.4       7.4
# 56567  06/05/2015 04:05:00 AM      509       8.1       8.1       8.1
# 56568  06/05/2015 04:15:00 AM      506       8.1       8.1       8.1
# 56569  06/05/2015 04:15:00 AM      509       8.1       8.1       8.1
#
#        light_max  light_min  light_avg  humidity_min  humidity_max  \
# 0           96.4       96.4       96.4          41.2          41.2
# 1           93.5       93.5       93.5          48.3          48.3
# 2           97.2       97.2       97.2          44.8          44.8
# 3           97.4       97.4       97.4          45.3          45.3
# 4           97.4       97.4       97.4          43.1          43.1
# 5           96.4       96.4       96.4          41.2          41.2
# 6           93.5       93.5       93.5          47.0          47.0
# 7           97.2       97.2       97.2          44.5          44.5
# 8           97.4       97.4       97.4          45.3          45.3
# 9           97.4       97.4       97.4          43.7          43.7
# 10          96.4       96.4       96.4          41.0          41.0
# 11          94.8       94.8       94.8          44.5          44.5
# 12          96.3       96.3       96.3          43.1          43.1
# 13          97.6       97.6       97.6          43.4          43.4
# 14          97.8       97.8       97.8          46.6          46.6
# 15          98.2       98.2       98.2          44.5          44.5
# 16          98.0       98.0       98.0          42.9          42.9
# 17          98.2       98.2       98.2          42.6          42.6
# 18          97.6       97.6       97.6          47.3          47.3
# 19          97.0       97.0       97.0          46.9          46.9
# 20          96.7       96.7       96.7          49.1          49.1
# 21          97.8       97.8       97.8          45.9          45.9
# 22          96.4       96.4       96.4          48.1          48.1
# 23          95.7       95.7       95.7          48.1          48.1
# 24          94.2       94.2       94.2          52.2          52.2
# 25          95.6       95.6       95.6          49.4          49.4
# 26          93.6       93.6       93.6          53.3          53.3
# 27          94.7       94.7       94.7          52.6          52.6
# 28          94.0       94.0       94.0          52.1          52.1
# 29          96.8       96.8       96.8          48.5          48.5
# ...          ...        ...        ...           ...           ...
# 56540        6.1        6.1        6.1          56.5          56.5
# 56541        2.3        2.3        2.3          64.5          64.5
# 56542        5.6        5.6        5.6          56.2          56.2
# 56543        2.4        2.4        2.4          64.4          64.4
# 56544        1.9        1.9        1.9          54.6          54.6
# 56545        2.4        2.4        2.4          64.7          64.7
# 56546        2.5        2.5        2.5          63.6          63.6
# 56547        2.3        2.3        2.3          54.4          54.4
# 56548        2.5        2.5        2.5          63.6          63.6
# 56549        2.3        2.3        2.3          54.3          54.3
# 56550        2.5        2.5        2.5          64.1          64.1
# 56551        2.3        2.3        2.3          53.8          53.8
# 56552        2.4        2.4        2.4          63.7          63.7
# 56553        2.2        2.2        2.2          54.6          54.6
# 56554        2.4        2.4        2.4          64.4          64.4
# 56555        2.4        2.4        2.4          64.2          64.2
# 56556        2.3        2.3        2.3          54.8          54.8
# 56557        2.4        2.4        2.4          64.7          64.7
# 56558        8.2        8.2        8.2          56.3          56.3
# 56559        2.5        2.5        2.5          63.9          63.9
# 56560        2.5        2.5        2.5          64.4          64.4
# 56561        2.5        2.5        2.5          64.4          64.4
# 56562        2.5        2.5        2.5          63.7          63.7
# 56563        3.8        3.8        3.8          53.8          53.8
# 56564        2.6        2.6        2.6          64.2          64.2
# 56565        2.6        2.6        2.6          63.4          63.4
# 56566        3.9        3.9        3.9          54.4          54.4
# 56567        2.6        2.6        2.6          63.9          63.9
# 56568        8.4        8.4        8.4          55.4          55.4
# 56569        2.6        2.6        2.6          63.7          63.7
#
#        humidity_avg   latitude   longitude  elevation           location
# 0              41.2 -37.813408  144.979492      30.10    Fitzroy Gardens
# 1              48.3 -37.813073  144.980406      29.91    Fitzroy Gardens
# 2              44.8 -37.814922  144.982258      38.79    Fitzroy Gardens
# 3              45.3 -37.814610  144.979018      22.57    Fitzroy Gardens
# 4              43.1 -37.814808  144.980999      29.96    Fitzroy Gardens
# 5              41.2 -37.813408  144.979492      30.10    Fitzroy Gardens
# 6              47.0 -37.813073  144.980406      29.91    Fitzroy Gardens
# 7              44.5 -37.814922  144.982258      38.79    Fitzroy Gardens
# 8              45.3 -37.814610  144.979018      22.57    Fitzroy Gardens
# 9              43.7 -37.814808  144.980999      29.96    Fitzroy Gardens
# 10             41.0 -37.813408  144.979492      30.10    Fitzroy Gardens
# 11             44.5 -37.820354  144.940482        NaN  Docklands Library
# 12             43.1 -37.819500  144.941889        NaN  Docklands Library
# 13             43.4 -37.819712  144.941325        NaN  Docklands Library
# 14             46.6 -37.819904  144.940485        NaN  Docklands Library
# 15             44.5 -37.820354  144.940482        NaN  Docklands Library
# 16             42.9 -37.819500  144.941889        NaN  Docklands Library
# 17             42.6 -37.819712  144.941325        NaN  Docklands Library
# 18             47.3 -37.819904  144.940485        NaN  Docklands Library
# 19             46.9 -37.819904  144.940485        NaN  Docklands Library
# 20             49.1 -37.819904  144.940485        NaN  Docklands Library
# 21             45.9 -37.819500  144.941889        NaN  Docklands Library
# 22             48.1 -37.819904  144.940485        NaN  Docklands Library
# 23             48.1 -37.819500  144.941889        NaN  Docklands Library
# 24             52.2 -37.819904  144.940485        NaN  Docklands Library
# 25             49.4 -37.819500  144.941889        NaN  Docklands Library
# 26             53.3 -37.820354  144.940482        NaN  Docklands Library
# 27             52.6 -37.819904  144.940485        NaN  Docklands Library
# 28             52.1 -37.820354  144.940482        NaN  Docklands Library
# 29             48.5 -37.819500  144.941889        NaN  Docklands Library
# ...             ...        ...         ...        ...                ...
# 56540          56.5 -37.820354  144.940482       0.71  Docklands Library
# 56541          64.5 -37.819904  144.940485       0.03  Docklands Library
# 56542          56.2 -37.820354  144.940482       0.71  Docklands Library
# 56543          64.4 -37.819904  144.940485       0.03  Docklands Library
# 56544          54.6 -37.819712  144.941325       2.74  Docklands Library
# 56545          64.7 -37.819904  144.940485       0.03  Docklands Library
# 56546          63.6 -37.819904  144.940485       0.03  Docklands Library
# 56547          54.4 -37.819712  144.941325       2.74  Docklands Library
# 56548          63.6 -37.819904  144.940485       0.03  Docklands Library
# 56549          54.3 -37.819712  144.941325       2.74  Docklands Library
# 56550          64.1 -37.819904  144.940485       0.03  Docklands Library
# 56551          53.8 -37.819712  144.941325       2.74  Docklands Library
# 56552          63.7 -37.819904  144.940485       0.03  Docklands Library
# 56553          54.6 -37.819712  144.941325       2.74  Docklands Library
# 56554          64.4 -37.819904  144.940485       0.03  Docklands Library
# 56555          64.2 -37.819904  144.940485       0.03  Docklands Library
# 56556          54.8 -37.819712  144.941325       2.74  Docklands Library
# 56557          64.7 -37.819904  144.940485       0.03  Docklands Library
# 56558          56.3 -37.820354  144.940482       0.71  Docklands Library
# 56559          63.9 -37.819904  144.940485       0.03  Docklands Library
# 56560          64.4 -37.819904  144.940485       0.03  Docklands Library
# 56561          64.4 -37.819904  144.940485       0.03  Docklands Library
# 56562          63.7 -37.819904  144.940485       0.03  Docklands Library
# 56563          53.8 -37.819712  144.941325       2.74  Docklands Library
# 56564          64.2 -37.819904  144.940485       0.03  Docklands Library
# 56565          63.4 -37.819904  144.940485       0.03  Docklands Library
# 56566          54.4 -37.819712  144.941325       2.74  Docklands Library
# 56567          63.9 -37.819904  144.940485       0.03  Docklands Library
# 56568          55.4 -37.820354  144.940482       0.71  Docklands Library
# 56569          63.7 -37.819904  144.940485       0.03  Docklands Library
#
# [56570 rows x 15 columns]

# %%
data.boardid.unique()
# Out:
# array([508, 505, 507, 502, 501, 506, 511, 510, 509], dtype=int64)

# %%
(data[data.location == 'Fitzroy Gardens']).boardid.unique()
# Out:
# array([508, 505, 507, 502, 501], dtype=int64)

# %%
len(data.boardid[data.boardid == 501])
# Out:
# 2903

# %% [markdown]
# Try to print out the folowing information automaticaly with 5-6 lines of code ([for-loop](https://www.w3schools.com/python/python_for_loops.asp)):

# %%
for location in data.location.unique():
    print(location)
    for i in sorted((data[data.location == location]).boardid.unique()):
        print('\tboard ', i, '- rows', len(data.boardid[data.boardid == i]))
# Out:
# Fitzroy Gardens
# 	board  501 - rows 2903
# 	board  502 - rows 2725
# 	board  505 - rows 2915
# 	board  507 - rows 2918
# 	board  508 - rows 2728
# Docklands Library
# 	board  506 - rows 6626
# 	board  509 - rows 19119
# 	board  510 - rows 12038
# 	board  511 - rows 4598

# %% [markdown]
# ## Median (aka expected value)

# %% [markdown]
# You'd like to have a function that takes an unsorted pandas.Series object (or a list) and returns a median for it.
#
# Sort the serie: https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.sort_values.html (or your list).
#
# There are two opotions: odd and even number of elements.
#
# If the number is odd, return an element with the index 'length of serie floor divided by 2'
#
# If the number is even, return a half sum of two middle elements.
#
# You can use `.iloc[]` to access the position of a row if pandas.Series object. Remember that the position is zero-based. https://stackoverflow.com/a/31593712

# %%
import numpy as np

def median(series):
    sorted_series = sorted(series.replace(np.nan, data.elevation.mean()))
    n = len(series)
#     print(sorted_series)
    if n == 0:
        return None
    if n % 2 == 1: #Odd
        return sorted_series[n // 2]
    if n % 2 == 0: #Even
        i = n // 2
        return (sorted_series[i-1] + sorted_series[i]) / 2

# %%
df = data.describe().T

# %%
df
# Out:
#                 count        mean        std         min         25%  \
# boardid       56570.0  507.918738   2.673337  501.000000  506.000000
# temp_max      56570.0   18.522650   5.498701    4.200000   14.800000
# temp_min      56570.0   18.522650   5.498701    4.200000   14.800000
# temp_avg      56570.0   18.522650   5.498701    4.200000   14.800000
# light_max     56570.0   48.674527  43.973493    0.000000    2.900000
# light_min     56570.0   48.674527  43.973493    0.000000    2.900000
# light_avg     56570.0   48.674527  43.973493    0.000000    2.900000
# humidity_min  56570.0   49.431043  13.413633  -24.900000   41.700000
# humidity_max  56570.0   49.431043  13.413633  -24.900000   41.700000
# humidity_avg  56570.0   49.431043  13.413633  -24.900000   41.700000
# latitude      56570.0  -37.818444   0.002513  -37.820354  -37.819904
# longitude     56570.0  144.950806   0.017177  144.940482  144.940485
# elevation     34975.0   12.973810  14.777655    0.030000    0.030000
#
#                      50%         75%         max
# boardid       509.000000  510.000000  511.000000
# temp_max       17.700000   21.900000   45.200000
# temp_min       17.700000   21.900000   45.200000
# temp_avg       17.700000   21.900000   45.200000
# light_max      49.900000   94.900000   98.700000
# light_min      49.900000   94.900000   98.700000
# light_avg      49.900000   94.900000   98.700000
# humidity_min   51.000000   58.700000  102.500000
# humidity_max   51.000000   58.700000  102.500000
# humidity_avg   51.000000   58.700000  102.500000
# latitude      -37.819712  -37.814922  -37.813073
# longitude     144.941325  144.979018  144.982258
# elevation       2.740000   29.910000   38.790000

# %%
for location in data.location.unique():
    
    print(location, 
          'temp', median(data[data.location == location].temp_avg), 
          'light', median(data[data.location == location].light_avg), 
          'humidity', median(data[data.location == location].humidity_avg))
    
    for i in sorted((data[data.location == location]).boardid.unique()):
        print('\tboard', i, '- elevation', median(data.elevation[data.boardid == i]))
        print('\t\t temp \t\t', median(data.temp_avg[data.boardid == i]))
        print('\t\t light \t\t', median(data.light_avg[data.boardid == i]))
        print('\t\t humidity \t', median(data.humidity_avg[data.boardid == i]))
#         print('\tboard ', i, '- elevation', len(data.boardid[data.boardid == i]))
# Out:
# Fitzroy Gardens temp 19.0 light 83.9 humidity 47.7
# 	board 501 - elevation 29.96
# 		 temp 		 19.0
# 		 light 		 88.2
# 		 humidity 	 47.3
# 	board 502 - elevation 22.57
# 		 temp 		 18.1
# 		 light 		 84.6
# 		 humidity 	 49.9
# 	board 505 - elevation 29.91
# 		 temp 		 20.0
# 		 light 		 78.3
# 		 humidity 	 51.0
# 	board 507 - elevation 38.79
# 		 temp 		 19.0
# 		 light 		 86.8
# 		 humidity 	 48.3
# 	board 508 - elevation 30.1
# 		 temp 		 19.0
# 		 light 		 83.25
# 		 humidity 	 43.3
# Docklands Library temp 17.4 light 13.1 humidity 51.9
# 	board 506 - elevation 12.9738095783
# 		 temp 		 16.5
# 		 light 		 8.5
# 		 humidity 	 48.6
# 	board 509 - elevation 0.03
# 		 temp 		 17.4
# 		 light 		 29.1
# 		 humidity 	 56.2
# 	board 510 - elevation 2.74
# 		 temp 		 17.1
# 		 light 		 73.75
# 		 humidity 	 49.2
# 	board 511 - elevation 12.9738095783
# 		 temp 		 18.7
# 		 light 		 13.55
# 		 humidity 	 50.2

# %% [markdown]
# You can use this `median` function to produce the median-answer.
#
# Make use of https://www.w3schools.com/python/ref_string_replace.asp

# %% [markdown]
# `Medians for locations:
#
#  Fitzroy Gardens
# 	 temp     	 19.0
# 	 light    	 83.9
# 	 humidity 	 47.7
#
# 	board 501 - elevation 29.96
# 		 temp     	 19.0
# 		 light    	 88.2
# 		 humidity 	 47.3
#
# 	board 502 - elevation 22.57
# 		 temp     	 18.1
# 		 light    	 84.6
# 		 humidity 	 49.9
#
# 	board 505 - elevation 29.91
# 		 temp     	 20.0
# 		 light    	 78.3
# 		 humidity 	 51.0
#
# 	board 507 - elevation 38.79
# 		 temp     	 19.0
# 		 light    	 86.8
# 		 humidity 	 48.3
#
# 	board 508 - elevation 30.1
# 		 temp     	 19.0
# 		 light    	 83.25
# 		 humidity 	 43.3
#
#  Docklands Library
# 	 temp     	 17.4
# 	 light    	 13.1
# 	 humidity 	 51.9
#
# 	board 506 - elevation 0.71
# 		 temp     	 16.5
# 		 light    	 8.5
# 		 humidity 	 48.6
#
# 	board 509 - elevation 0.03
# 		 temp     	 17.4
# 		 light    	 29.1
# 		 humidity 	 56.2
#
# 	board 510 - elevation 2.74
# 		 temp     	 17.1
# 		 light    	 73.75
# 		 humidity 	 49.2
#
# 	board 511 - elevation 3.75
# 		 temp     	 18.7
# 		 light    	 13.55
# 		 humidity 	 50.2`

# %% [markdown]
# ## Standard deviation

# %% [markdown]
# Write a function that takes pandas.Series object and returns standard deviation.
#
# First calculate `mean = serie.sum() / serie.count()`
#
# Then make a Series object which contains `squares_off_difference` between every measured value and the `mean`.
#
# Then return sqrt of ratio of `squares_off_difference.sum()` to number of elements in `serie` minus 1.

# %%
#     sqrt(sum((x - mean)**2 for x in lst) / len(lst))

from math import sqrt

def st_dev(series):
    sorted_series = pd.Series(series.replace(np.nan, data.elevation.mean()))
    
    mean = sorted_series.sum() / sorted_series.count()
    squares_off_difference = [(x - mean) ** 2 for x in sorted_series]
    
    # your code here
    return sqrt(sum(squares_off_difference) / (sorted_series.count()-1))

# %%
st_dev(data.elevation)
# Out:
# 11.619539882759764

# %% [markdown]
# You can reuse your solution for median printout, now with `st_dev` function

# %%
columns = ['temp_avg', 'light_avg', 'humidity_avg']
print ('St. dev. for locations:')
for location in data.location.unique():
    
    print(location, 
          'temp %.2f' % st_dev(data[data.location == location].temp_avg), 
          'light %.2f' % st_dev(data[data.location == location].light_avg), 
          'humidity %.2f' % st_dev(data[data.location == location].humidity_avg))
    
    for i in sorted((data[data.location == location]).boardid.unique()):
        print('\tboard', i, '- elevation', st_dev(data.elevation[data.boardid == i]))
        print('\t\t temp \t\t %.2f' % st_dev(data.temp_avg[data.boardid == i]))
        print('\t\t light \t\t %.2f' % st_dev(data.light_avg[data.boardid == i]))
        print('\t\t humidity \t %.2f' % st_dev(data.humidity_avg[data.boardid == i]))
# Out:
# St. dev. for locations:
# Fitzroy Gardens temp 4.74 light 43.51 humidity 16.90
# 	board 501 - elevation 1.0020378588972956e-12
# 		 temp 		 5.26
# 		 light 		 44.84
# 		 humidity 	 28.19
# 	board 502 - elevation 2.6650242992548287e-13
# 		 temp 		 4.58
# 		 light 		 43.38
# 		 humidity 	 12.00
# 	board 505 - elevation 2.1284406090701902e-12
# 		 temp 		 4.37
# 		 light 		 41.71
# 		 humidity 	 11.77
# 	board 507 - elevation 2.259913169563088e-12
# 		 temp 		 4.84
# 		 light 		 44.49
# 		 humidity 	 12.83
# 	board 508 - elevation 3.5178313649241403e-13
# 		 temp 		 4.43
# 		 light 		 42.99
# 		 humidity 	 11.28
# Docklands Library temp 5.67 light 43.97 humidity 11.88
# 	board 506 - elevation 6.128671983219053
# 		 temp 		 5.38
# 		 light 		 39.27
# 		 humidity 	 14.65
# 	board 509 - elevation 6.435235463833894
# 		 temp 		 5.52
# 		 light 		 44.77
# 		 humidity 	 11.81
# 	board 510 - elevation 5.117116203761689
# 		 temp 		 6.06
# 		 light 		 45.24
# 		 humidity 	 8.62
# 	board 511 - elevation 3.787572143282714
# 		 temp 		 5.22
# 		 light 		 41.32
# 		 humidity 	 11.64

# %%
st_dev(data.elevation[data.boardid == 506])
# Out:
# 6.128671983219053

# %%
st_dev(data.elevation[data.boardid == 501])
# Out:
# 1.0020378588972956e-12

# %%
import numpy as np

np.std(data.elevation[data.boardid == 506])
# Out:
# 2.6201263381153694e-14

# %% [markdown]
# ## Visualisation

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Have a look at https://pandas.pydata.org/pandas-docs/stable/timeseries.html
#
# Have you noticed that column `timestamp` in our data is a string? We have to convert it to pandas.Timestamp to be able to plot measurements correctly.
#
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.to_datetime.html

# %%
# %time data['ts'] = pd.to_datetime(data.timestamp)
data.ts.describe()
# Out:
# Wall time: 10.3 s
# count                   56570
# unique                  29779
# top       2014-12-23 03:55:00
# freq                        8
# first     2014-12-15 01:40:00
# last      2015-06-05 04:15:00
# Name: ts, dtype: object

# %%
data.head()
# Out:
#                 timestamp  boardid  temp_max  temp_min  temp_avg  light_max  \
# 0  12/15/2014 01:40:00 AM      508      21.6      21.6      21.6       96.4
# 1  12/15/2014 01:40:00 AM      505      23.2      23.2      23.2       93.5
# 2  12/15/2014 01:45:00 AM      507      21.6      21.6      21.6       97.2
# 3  12/15/2014 01:45:00 AM      502      21.3      21.3      21.3       97.4
# 4  12/15/2014 01:45:00 AM      501      22.9      22.9      22.9       97.4
#
#    light_min  light_avg  humidity_min  humidity_max  humidity_avg   latitude  \
# 0       96.4       96.4          41.2          41.2          41.2 -37.813408
# 1       93.5       93.5          48.3          48.3          48.3 -37.813073
# 2       97.2       97.2          44.8          44.8          44.8 -37.814922
# 3       97.4       97.4          45.3          45.3          45.3 -37.814610
# 4       97.4       97.4          43.1          43.1          43.1 -37.814808
#
#     longitude  elevation         location                  ts
# 0  144.979492      30.10  Fitzroy Gardens 2014-12-15 01:40:00
# 1  144.980406      29.91  Fitzroy Gardens 2014-12-15 01:40:00
# 2  144.982258      38.79  Fitzroy Gardens 2014-12-15 01:45:00
# 3  144.979018      22.57  Fitzroy Gardens 2014-12-15 01:45:00
# 4  144.980999      29.96  Fitzroy Gardens 2014-12-15 01:45:00

# %% [markdown]
# If it takes too long time to convert, try to help pandas and define time format you are reading:
#
# https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior

# %% [markdown]
# Be advised that you may want to `data.set_index('ts')` and use non unique index but there will be a performance penalty: https://stackoverflow.com/a/16629125

# %% [markdown]
# Now you can easily plot all measurements from some location and from some period of time.
#
# For example: average temperature at *Fitzroy Gardens* only from 2014.

# %% [markdown]
# Can you color separate different boards?

# %% [markdown]
# ### Plot temp_avg of Fitzroy Gardens different boards

# %%
plt.figure(figsize=(18,5))
location_filter = data.location == 'Fitzroy Gardens'
time_filter = data.ts < pd.Timestamp('2015-01-01')
data_filtered = data[location_filter & time_filter]
boards = data_filtered.boardid.unique()
colors = ['g','r','m','b','k']

for board, color in zip(boards,colors):
    plt.plot(data_filtered.ts[data_filtered.boardid == board], 
             data_filtered.temp_avg[data_filtered.boardid == board], ',', 
             c=color, 
             alpha=.9, marker='*', markersize=5)
plt.legend(labels=boards)

# %% [markdown]
# ### Plot temp_avg of Docklands Library different boards

# %%
plt.figure(figsize=(18,5))
location_filter = data.location == 'Docklands Library'
time_filter = data.ts < pd.Timestamp('2015-01-01')
data_filtered = data[location_filter & time_filter]
boards = data_filtered.boardid.unique()
colors = ['g','r','m','b','k']

for board, color in zip(boards,colors):
    plt.plot(data_filtered.ts[data_filtered.boardid == board], 
             data_filtered.temp_avg[data_filtered.boardid == board], ',', 
             c=color, 
             alpha=.9, marker='*', markersize=5)
plt.legend(labels=boards)

# %%
# import seaborn as sns

# plt.figure(figsize=(12,8))
# sns.lineplot(x=data_filtered.ts, y=data_filtered.temp_avg, data=data_filtered, hue=data_filtered.boardid)

# %% [markdown]
# Can your plot the median?
